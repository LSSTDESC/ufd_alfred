# %%
from lsst.daf.butler import Butler
from useful_functions_global import *
import pandas as pd
import numpy as np
import healpy as hp
from astropy.table import Table, vstack
import fitsio
import matplotlib.pyplot as plt
from ugali.utils.projector import match
#from astropy.coordinates import SkyCoord
#import astropy.units as u
import gc
#from concurrent.futures import ThreadPoolExecutor
import time


my_path =  '/sdf/data/rubin/user/kexcel/'
my_plotspath = my_path + 'plots/'

survey = 'dp2'
## unembargoed repo
mainrepo="/repo/main"

## After the migration, w_2026_19 (or later) or v30_0_8_rc4 will be needed to use dp2_prep <- from Slack
if survey == 'dp2':
    repo = "dp2_prep"
    collection = ['LSSTCam/runs/DRP/DP2/v30_0_0/DM-53881/stage1',
                  'LSSTCam/runs/DRP/DP2/v30_0_0/DM-53881/stage2',
                  'LSSTCam/runs/DRP/DP2/v30_0_6_rc1/DM-53881/stage3',
                  'LSSTCam/runs/DRP/DP2/v30_0_0/DM-53881/stage4']
    #field = 'edfs'
    #collection = [f'u/dtaranu/DM-50135/DP2/v30_0_8/matched_{field}']
    skymap = 'lsst_cells_v2'
elif survey == 'dp1':
    repo = "dp1"
    collection = ["LSSTComCam/DP1"]
    skymap = 'lsst_cells_v1'

# %%
def load_lsst_data(field_or_tract):
    print('Start LSST data load')
    start_time = time.perf_counter()

    INCOLS = [
        'coord_ra',
        'coord_dec',
        'detect_isIsolated',
        'refExtendedness',
        'tract', 'patch'
    ]
    if survey=='dp1':
        bands = 'ugrizy'
        for band in bands:
            INCOLS += [
                f'{band}_psfFlux',
                f'{band}_cModelFlux',
                f'{band}_cModelFluxErr',
                f'{band}_psfFluxErr',
                f'{band}_extendedness',
                f'{band}_extendedness_flag',
                f'{band}_psfFlux_flag'
            ]
            INCOLS += [f'{band}_sizeExtendedness', f'{band}_sizeExtendedness_flag']
    ## new classifier from Dan Taranu = {band}_model_extendedness
    ## old classifier from DM is {band}_extendedness or {band}_SizeExtendedness - these might become depreciated in DP2 or DR1
    elif survey=='dp2':
        INCOLS += ['griz_model_extendedness']
        bands = 'grizy'
        for band in bands:
            INCOLS += [
                f'{band}_psfFlux',
                f'{band}_cModelFlux',
                f'{band}_cModelFluxErr',
                f'{band}_psfFluxErr',
                f'{band}_extendedness',
                f'{band}_extendedness_flag',
                f'{band}_psfFlux_flag'
            ]
            INCOLS += [f'{band}_model_extendedness']
    
    butler = Butler(repo, collections=collection)
    registry=butler.registry
    
    ## this is for loading data in by field name
    if type(field_or_tract) == str:
        tract_list = get_tract(field)
        raw_lsst_list = []
        for i in range(len(tract_list)):
            tract = tract_list[i]
            raw_lsst_list.append(butler.get('object', dataId={'skymap': skymap, 'tract': tract}, collections=collection,
                                parameters={"columns":INCOLS}))
        raw_lsst = vstack(raw_lsst_list)
        del raw_lsst_list,tract_list
        gc.collect()
    ## for loading data in by tract number
    elif type(field_or_tract) == int:
        raw_lsst = butler.get('object', dataId={'skymap': skymap, 'tract': field_or_tract}, collections=collection,
                                parameters={"columns":INCOLS})
    # End the timer
    end_time = time.perf_counter()
    # Calculate and print elapsed time
    print(f'End LSST data load. Execution time: {(end_time - start_time):.6f} seconds')
    return raw_lsst

# %%
def load_euclid_file(pix):
    columns_to_load = ['RIGHT_ASCENSION','DECLINATION',
                       'POINT_LIKE_PROB', 'POINT_LIKE_FLAG',
                       'ELLIPTICITY', 'MUMAX_MINUS_MAG',
                       'FLUX_VIS_PSF', 'FLUXERR_VIS_PSF',
                       'SPURIOUS_FLAG','DET_QUALITY_FLAG', 'FWHM']
    num = 2
    for band in ['VIS', 'Y', 'J', 'H']:
        columns_to_load += [f'FLAG_{band}',f'FLUX_{band}_{num}FWHM_APER', f'FLUXERR_{band}_{num}FWHM_APER']
    try:
        euclid_path = "/sdf/group/rubin/shared/euclid/q1/catalogs/"
        raw_euclid = Table(fitsio.read(euclid_path + f"euclid_q1_mer_final_{pix:05d}.fits", columns = columns_to_load))
    except:
        print('Exception')
        raw_euclid = Table()
    return raw_euclid

# %%
def euclid_merge(lsst_datafile, field_or_tract, visualization = False):
    ## coarser resolution to load in Euclid files, which follow nside = 64 pixel name convention
    nside = 64
    lsst_ra = lsst_datafile['coord_ra']
    lsst_dec = lsst_datafile['coord_dec']
    ## converting our queried LSST ra and dec into pixels
    lsst_pix64 = hp.ang2pix(nside, lsst_ra, lsst_dec, lonlat=True, nest=True)
    lsst_upix64 = np.unique(lsst_pix64)
    
    print('Start Euclid data load')
    start_time = time.perf_counter()
    #with ThreadPoolExecutor() as executor:
    #    euclid = vstack(list(executor.map(load_euclid_file, lsst_upix64)))
    euclid_list = []
    for pix in lsst_upix64:
        euclid_list.append(load_euclid_file(pix))
    euclid = vstack(euclid_list)
    if (len(euclid['RIGHT_ASCENSION']) == 0) or (len(euclid['DECLINATION']) == 0):
        print('No euclid data for ', field_or_tract)
        return
    del nside, lsst_pix64, lsst_upix64, euclid_list
    gc.collect()
    end_time = time.perf_counter()
    print(f'End Euclid data load. Execution time: {(end_time - start_time):.6f} seconds')

    print('Start area overlap masking')
    start_time = time.perf_counter()
    ## now get greater resolution to match up
    NSIDE=4096
    ## get the pixels of LSST data
    lsst_upix4096, lsst_cts = np.unique(hp.ang2pix(NSIDE, lsst_ra, lsst_dec, lonlat=True), return_counts=True)
    ## then get the pixels of Euclid data
    euclid_pix4096 = hp.ang2pix(NSIDE, euclid['RIGHT_ASCENSION'], euclid['DECLINATION'], lonlat=True)
    ## Euclid has more coverage right now. We only keep the sources that lie in the LSST coverage
    mask = np.isin(euclid_pix4096, lsst_upix4096) #[lsst_cts > 8])
    euclid_field = euclid[mask]
    del NSIDE, mask, lsst_upix4096, lsst_cts, euclid_pix4096, euclid
    gc.collect()
    end_time = time.perf_counter()
    print(f'End area overlap masking. Execution time: {(end_time - start_time):.6f} seconds')
    
    print('Start catalog matching')
    start_time = time.perf_counter()
    ## match() is from ugali tools -- matching LSST and Euclid sources
    if len(euclid_field['RIGHT_ASCENSION']) == 0:
        return
    indexlsst, indexeuclid, ds = match(lsst_ra, lsst_dec, 
                                       euclid_field['RIGHT_ASCENSION'], euclid_field['DECLINATION'], 
                                       tol = 0.0003)
    #print('index lsst:', '\n', indexlsst[0:20])
    #print('index euclid:', '\n', indexeuclid[0:20])
    matches_lsst = lsst_datafile[indexlsst]
    unmatched_lsst = lsst_datafile[~indexlsst]
    #print(matches_lsst.columns)
    matches_euclid = euclid_field[indexeuclid]
    unmatched_euclid = euclid_field[~indexeuclid]
    if len(matches_lsst) != len(matches_euclid):
        print("Something isn't right: those lengths don't match")
    del indexlsst, indexeuclid, lsst_ra, lsst_dec
    gc.collect()
    end_time = time.perf_counter()
    print(f'End catalog matching. Execution time: {(end_time - start_time):.6f} seconds')

    if visualization == True:
        ## Match Verification
        b = 60
        #1D histogram of matches and not matches
        fig, ax = plt.subplots(1,1, figsize=(13,5))
        match_vis_mag = flux2mag(matches_euclid['FLUX_VIS_2FWHM_APER']*(10**3))
        unmatch_vis_mag = flux2mag(unmatched_euclid['FLUX_VIS_2FWHM_APER']*(10**3))
        total_vis_mag = flux2mag(euclid_field['FLUX_VIS_2FWHM_APER']*(10**3))
        plt.hist(match_vis_mag, bins = b, histtype = 'step', color='b', label = 'Matched Euclid Sources')
        plt.hist(unmatch_vis_mag, bins = b, histtype = 'step', color='r', label = 'Unmatched Euclid Sources')
        plt.hist(total_vis_mag, bins = b, histtype = 'step', color='k', label = 'Total Euclid Sources')
        plt.xlabel('FLUX_VIS_2FWHM_APER mag')
        plt.xlim(16,36)
        plt.ylabel('Number counts')
        plt.yscale('log')
        plt.title(f'Tract {tract}: Euclid Source Match/Unmatch')
        plt.legend()
        plt.show()
        
        match_i_mag = flux2mag(matches_lsst['i_psfFlux'])
        unmatch_i_mag = flux2mag(unmatched_lsst['i_psfFlux'])
        total_i_mag = flux2mag(lsst_datafile['i_psfFlux'])
        fig, ax = plt.subplots(1,1, figsize=(13,5))
        plt.hist(match_i_mag, bins = b, histtype = 'step', color='c', label = 'Matched LSST Sources')
        plt.hist(unmatch_i_mag, bins = b, histtype = 'step', color='r', label = 'Unmatched LSST Sources')
        plt.hist(total_i_mag, bins = b, histtype = 'step', color='k', label = 'Total LSST Sources')
        plt.xlabel('i_psfFlux mag')
        plt.xlim(16,36)
        plt.ylabel('Number counts')
        plt.yscale('log')
        plt.title(f'Tract {tract}: LSST Source Match/Unmatch')
        plt.legend()
        plt.show()

        #2D histogram of matches in Euclid and LSST, does it look the same?
        fig, ax = plt.subplots(1,2, figsize=(13,5))
        _, _, _, im = ax[0].hist2d(matches_euclid['RIGHT_ASCENSION'], matches_euclid['DECLINATION'], bins=100)
        plt.colorbar(im, ax=ax[0])
        ax[0].set(title = f'Tract {tract}: Matches in Euclid', ylabel = "Dec (deg)", xlabel = "RA (deg)")
        ax[0].invert_xaxis()
        _, _, _, im = ax[1].hist2d(matches_lsst['coord_ra'], matches_lsst['coord_dec'], bins=100)
        plt.colorbar(im, ax=ax[1])
        ax[1].set(title = f'Tract {tract}: Matches in LSST', ylabel = "Dec (deg)", xlabel = "RA (deg)")
        ax[1].invert_xaxis()
        plt.show()

        '''
        #histogram of separation
        ds = ds * 3600 #ds is in degrees, want to plot in arcsecs
        #I forced in the function that matches would be <1"
        plt.hist(ds, histtype='step', range=(0,1))
        plt.xlabel('separation [arcsec]')
        plt.title(f'Tract {tract}: Matched Source Separation')
        plt.tight_layout()
        plt.show()

        #checking that dec and DECLINATION relation is slope of 1
        plt.scatter(merged_df['coord_dec'],merged_df['DECLINATION'],)
        '''

    ## now merging our matches into one catalog with all LSST and Euclid columns
    print('Start catalog merge')
    start_time = time.perf_counter()
    lsst_df = matches_lsst.to_pandas()
    euclid_df = matches_euclid.to_pandas()
    lsst_df['_match_id'] = np.arange(len(lsst_df))
    euclid_df['_match_id'] = np.arange(len(euclid_df))
    merged_df = pd.merge(lsst_df, euclid_df, on='_match_id').drop(columns='_match_id')
    del lsst_df, euclid_df, matches_lsst, matches_euclid, unmatched_lsst, unmatched_euclid, ds
    gc.collect()
    merged_df.to_parquet(my_path + f'/euclid_data/q1/{field_or_tract}_{survey}_euclid_merged.parquet', 
                         index=False, compression = 'snappy')
    end_time = time.perf_counter()
    print(f'End catalog merge. Merged catalog saved. Execution time: {(end_time - start_time):.6f} seconds')

    ## comment/uncomment as needed for debugging
    del merged_df, euclid_field, lsst_datafile
    gc.collect()
    #return merged_df #, euclid_field, lsst_datafile

# %%
tract_list = get_tract('EDFS')
for i in range(len(tract_list)):
    tract = tract_list[i]
    print(tract)
    euclid_merge(load_lsst_data(tract), tract, 
                             visualization = False)
    print(' ')
# Out:
# 2078
# Start LSST data load
# End LSST data load. Execution time: 1.136391 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 1.619181 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.219021 seconds
# Start catalog matching
# End catalog matching. Execution time: 2.249042 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.260125 seconds
#
# 2079
# Start LSST data load
# End LSST data load. Execution time: 0.884720 seconds
# Start Euclid data load
# Exception
# Exception
# End Euclid data load. Execution time: 6.512639 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.318996 seconds
# Start catalog matching
# End catalog matching. Execution time: 4.695170 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 1.402767 seconds
#
# 2080
# Start LSST data load
# End LSST data load. Execution time: 1.265253 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 4.049653 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.306476 seconds
# Start catalog matching
# End catalog matching. Execution time: 20.738488 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.670323 seconds
#
# 2232
# Start LSST data load
# End LSST data load. Execution time: 0.891308 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 3.283257 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.244877 seconds
# Start catalog matching
# End catalog matching. Execution time: 3.228383 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.278188 seconds
#
# 2233
# Start LSST data load
# End LSST data load. Execution time: 1.055283 seconds
# Start Euclid data load
# End Euclid data load. Execution time: 7.828905 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.331949 seconds
# Start catalog matching
# End catalog matching. Execution time: 2.407530 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 2.208563 seconds
#
# 2234
# Start LSST data load
# End LSST data load. Execution time: 1.006932 seconds
# Start Euclid data load
# End Euclid data load. Execution time: 7.254050 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.375406 seconds
# Start catalog matching
# End catalog matching. Execution time: 1.363199 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 2.510544 seconds
#
# 2235
# Start LSST data load
# End LSST data load. Execution time: 0.978143 seconds
# Start Euclid data load
# End Euclid data load. Execution time: 16.073268 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.347647 seconds
# Start catalog matching
# End catalog matching. Execution time: 1.329207 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 2.285548 seconds
#
# 2236
# Start LSST data load
# End LSST data load. Execution time: 0.973680 seconds
# Start Euclid data load
# Exception
# Exception
# End Euclid data load. Execution time: 8.575132 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.364952 seconds
# Start catalog matching
# End catalog matching. Execution time: 4.210999 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 1.711319 seconds
#
# 2237
# Start LSST data load
# End LSST data load. Execution time: 0.862251 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 2.419100 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.231180 seconds
# Start catalog matching
# End catalog matching. Execution time: 1.409483 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.275816 seconds
#
# 2392
# Start LSST data load
# End LSST data load. Execution time: 0.866771 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 6.520017 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.254986 seconds
# Start catalog matching
# End catalog matching. Execution time: 2.531893 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.377630 seconds
#
# 2393
# Start LSST data load
# End LSST data load. Execution time: 0.992138 seconds
# Start Euclid data load
# End Euclid data load. Execution time: 7.589140 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.317697 seconds
# Start catalog matching
# End catalog matching. Execution time: 1.421762 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 2.235764 seconds
#
# 2394
# Start LSST data load
# End LSST data load. Execution time: 1.178145 seconds
# Start Euclid data load
# End Euclid data load. Execution time: 7.926580 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.395041 seconds
# Start catalog matching
# End catalog matching. Execution time: 1.551703 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 2.778072 seconds
#
# 2395
# Start LSST data load
# End LSST data load. Execution time: 1.069759 seconds
# Start Euclid data load
# End Euclid data load. Execution time: 31.311816 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.409520 seconds
# Start catalog matching
# End catalog matching. Execution time: 1.531522 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 2.394192 seconds
#
# 2396
# Start LSST data load
# End LSST data load. Execution time: 1.039703 seconds
# Start Euclid data load
# End Euclid data load. Execution time: 31.456235 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.370621 seconds
# Start catalog matching
# End catalog matching. Execution time: 1.473441 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 2.833672 seconds
#
# 2397
# Start LSST data load
# End LSST data load. Execution time: 1.713467 seconds
# Start Euclid data load
# End Euclid data load. Execution time: 17.776062 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.287278 seconds
# Start catalog matching
# End catalog matching. Execution time: 2.841202 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 2.278106 seconds
#
# 2557
# Start LSST data load
# End LSST data load. Execution time: 0.859245 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 5.238489 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.205666 seconds
# Start catalog matching
#
# 2558
# Start LSST data load
# End LSST data load. Execution time: 3.727185 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 8.071249 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.291660 seconds
# Start catalog matching
# End catalog matching. Execution time: 14.044061 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.495715 seconds
#
# 2559
# Start LSST data load
# End LSST data load. Execution time: 0.905903 seconds
# Start Euclid data load
# Exception
# End Euclid data load. Execution time: 214.799187 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.415370 seconds
# Start catalog matching
# End catalog matching. Execution time: 3.736291 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 2.074104 seconds
#
# 2560
# Start LSST data load
# End LSST data load. Execution time: 1.419917 seconds
# Start Euclid data load
# End Euclid data load. Execution time: 353.101581 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.400104 seconds
# Start catalog matching
# End catalog matching. Execution time: 1.570246 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 2.424285 seconds
#
# 2561
# Start LSST data load
# End LSST data load. Execution time: 1.138634 seconds
# Start Euclid data load
# End Euclid data load. Execution time: 239.901462 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.395846 seconds
# Start catalog matching
# End catalog matching. Execution time: 1.453059 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 2.290616 seconds
#
# 2562
# Start LSST data load
# End LSST data load. Execution time: 1.187767 seconds
# Start Euclid data load
# End Euclid data load. Execution time: 17.216913 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.277877 seconds
# Start catalog matching
# End catalog matching. Execution time: 5.634595 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 1.687942 seconds
#
# 2728
# Start LSST data load
# End LSST data load. Execution time: 2.459212 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 9.831841 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.244463 seconds
# Start catalog matching
# End catalog matching. Execution time: 1.326450 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.239116 seconds
#
# 2729
# Start LSST data load
# End LSST data load. Execution time: 0.963974 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 23.682770 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.321295 seconds
# Start catalog matching
# End catalog matching. Execution time: 9.241533 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.698923 seconds
#
# 2730
# Start LSST data load
# End LSST data load. Execution time: 2.230989 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 11.471665 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.318546 seconds
# Start catalog matching
# End catalog matching. Execution time: 16.126521 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.607407 seconds
#
# 2731
# Start LSST data load
# End LSST data load. Execution time: 2.326407 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 0.979618 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.237197 seconds
# Start catalog matching
# End catalog matching. Execution time: 1.603864 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.232584 seconds

# %%
tract_list = get_tract('ECDFS')
for i in range(len(tract_list)):
    tract = tract_list[i]
    print(tract)
    euclid_merge(load_lsst_data(tract), tract, visualization = False)
    print(' ')
# Out:
# 4848
# Start LSST data load
# End LSST data load. Execution time: 1.704688 seconds
# Start Euclid data load
# End Euclid data load. Execution time: 24.606382 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.285375 seconds
# Start catalog matching
# End catalog matching. Execution time: 1.439449 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 2.007392 seconds
#
# 4849
# Start LSST data load
# End LSST data load. Execution time: 1.275453 seconds
# Start Euclid data load
# End Euclid data load. Execution time: 32.109460 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.304127 seconds
# Start catalog matching
# End catalog matching. Execution time: 1.416200 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 1.953870 seconds
#
# 5063
# Start LSST data load
# End LSST data load. Execution time: 1.279927 seconds
# Start Euclid data load
# End Euclid data load. Execution time: 62.827057 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.298019 seconds
# Start catalog matching
# End catalog matching. Execution time: 1.374593 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 1.924386 seconds
#
# 4636
# Start LSST data load
# End LSST data load. Execution time: 0.853396 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 1.116649 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.193665 seconds
# Start catalog matching
# End catalog matching. Execution time: 1.542189 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.176995 seconds
#
# 4637
# Start LSST data load
# End LSST data load. Execution time: 1.116638 seconds
# Start Euclid data load
# Exception
# Exception
# End Euclid data load. Execution time: 1.427600 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.209847 seconds
# Start catalog matching
# End catalog matching. Execution time: 6.422757 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.546229 seconds
#
# 4638
# Start LSST data load
# End LSST data load. Execution time: 0.875276 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 0.602205 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.178931 seconds
# Start catalog matching
# End catalog matching. Execution time: 3.082176 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.191128 seconds
#
# 4847
# Start LSST data load
# End LSST data load. Execution time: 1.191797 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 3.106708 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.204966 seconds
# Start catalog matching
# End catalog matching. Execution time: 17.697203 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.405360 seconds
#
# 4850
# Start LSST data load
# End LSST data load. Execution time: 0.970616 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 2.217163 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.232743 seconds
# Start catalog matching
# End catalog matching. Execution time: 12.436014 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.483868 seconds
#
# 5061
# Start LSST data load
# End LSST data load. Execution time: 0.772772 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 1.102996 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.154095 seconds
# Start catalog matching
# End catalog matching. Execution time: 0.421475 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.159239 seconds
#
# 5062
# Start LSST data load
# End LSST data load. Execution time: 1.055607 seconds
# Start Euclid data load
# Exception
# End Euclid data load. Execution time: 6.426513 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.327246 seconds
# Start catalog matching
# End catalog matching. Execution time: 1.471403 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 2.131542 seconds
#
# 5064
# Start LSST data load
# End LSST data load. Execution time: 0.940354 seconds
# Start Euclid data load
# Exception
# Exception
# End Euclid data load. Execution time: 4.717379 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.292705 seconds
# Start catalog matching
# End catalog matching. Execution time: 5.126666 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 4.583026 seconds
#
# 5065
# Start LSST data load
# End LSST data load. Execution time: 1.377364 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# Exception
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 0.218410 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.152121 seconds
# Start catalog matching
#
# 5279
# Start LSST data load
# End LSST data load. Execution time: 0.893648 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 4.790336 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.223283 seconds
# Start catalog matching
# End catalog matching. Execution time: 4.476186 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 1.485747 seconds
#
# 5280
# Start LSST data load
# End LSST data load. Execution time: 0.911332 seconds
# Start Euclid data load
# Exception
# End Euclid data load. Execution time: 6.474709 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.284620 seconds
# Start catalog matching
# End catalog matching. Execution time: 4.139270 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 3.496595 seconds
#
# 5281
# Start LSST data load
# End LSST data load. Execution time: 0.980615 seconds
# Start Euclid data load
# Exception
# Exception
# End Euclid data load. Execution time: 7.464817 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.234768 seconds
# Start catalog matching
# End catalog matching. Execution time: 4.695991 seconds
# Start catalog merge
# End catalog merge. Merged catalog saved. Execution time: 0.548123 seconds
#
# 5282
# Start LSST data load
# End LSST data load. Execution time: 0.843456 seconds
# Start Euclid data load
# Exception
# Exception
# Exception
# Exception
# Exception
# Exception
# End Euclid data load. Execution time: 0.210327 seconds
# Start area overlap masking
# End area overlap masking. Execution time: 0.146164 seconds
# Start catalog matching

# %%
## CODE FOR IF THE MERGE IS WEIRD

i_mag = flux2mag(lsst_datafile['i_psfFlux'])
vis_mag = flux2mag(euclid_field['FLUX_VIS_PSF']*10**3)

print(len(i_mag))

lsst_datafile1 = lsst_datafile #[(i_mag < 22)]
euclid_field1 = euclid_field #[(vis_mag < 22)]

plt.scatter(euclid_field1['RIGHT_ASCENSION'], euclid_field1['DECLINATION'], 
            marker = '+', label = 'Euclid Sources', #c = flux2mag(euclid_field1['FLUX_VIS_PSF']*10**3), 
           )
plt.scatter(lsst_datafile1['coord_ra'], lsst_datafile1['coord_dec'], 
            marker = 'x', label = 'LSST Sources', #c = flux2mag(lsst_datafile1['i_psfFlux']),
           )
plt.xlim(59.85, 59.84)
plt.xlabel('RA (deg)')
plt.ylim(-48.55,-48.54)
plt.ylabel('DEC (deg)')
#plt.colorbar()
plt.legend()
plt.title('Euclid and LSST before matching, \n restricted i_mag & vis_mag < 22')
plt.show()

ra_diff = (merged_df['RIGHT_ASCENSION'] - merged_df['coord_ra'])*3600
dec_diff = (merged_df['DECLINATION'] - merged_df['coord_dec'])*3600
plt.hist(ra_diff, bins = 100)
plt.title('Merged Catalog RA difference')
plt.xlabel('Euclid RA - LSST RA (arcsec)')
plt.xlim(-1,1)
plt.show()

plt.hist(dec_diff, bins = 100)
plt.xlim(-0.5,0.5)
plt.xlabel('Euclid DEC - LSST DEC (arcsec)')
plt.title('Merged Catalog DEC difference')
plt.show()
